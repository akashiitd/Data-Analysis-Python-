# %%
import os, sys, glob

import tkinter
from tkinter import *
import tkinter.messagebox as tm
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select

path = "D:\\Users\\703183779\\Downloads\\Leela"
os.makedirs(path)


    

class LoginFrame(Frame):
    def __init__(self, master):
        super().__init__(master)

        self.label_username = Label(self, text="Username")
        self.label_password = Label(self, text="Password")

        self.entry_username = Entry(self)
        self.entry_password = Entry(self, show="*")

        self.label_username.grid(row=0, sticky=E)
        self.label_password.grid(row=1, sticky=E)
        self.entry_username.grid(row=0, column=1)
        self.entry_password.grid(row=1, column=1)
        
        self.label_date = Label(self,text = "Date")
        self.entry_date = Entry(self)
        self.label_date.grid(row =3, sticky = E)
        self.entry_date.grid(row=3, column = 1)
        
#         """ OTP """
        
#         self.label_otp = Label(self,text ="OTP")
#         self.entry_otp = Entry(self)
#         self.label_otp.grid(row=4,sticky =E)
#         self.entry_otp.grid(row=4, column =1)
        self.checkbox = Checkbutton(self, text="Keep me logged in")
        self.checkbox.grid(columnspan=2)

        self.logbtn = Button(self, text="Login", command=self._login_btn_clicked)
        self.logbtn.grid(columnspan=2)
        
     
        
        
        self.pack()

    def _login_btn_clicked(self):
        # print("Clicked")
        username = self.entry_username.get()
        password = self.entry_password.get()
        date = self.entry_date.get()
        
        

        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument("--test-type")
        options.binary_location = "/usr/bin/chromium"
        driver = webdriver.Chrome(executable_path = r"D:\Users\703183779\Downloads\Chrome\chromedriver.exe")
        #drivp.raj.kumar@medtronic.comRiya@4321er.get("https://federation.medtronic.com/siteminderagent/forms/login-mdt-internet-ent.fcc?TYPE=33554433&REALMOID=06-000ccae4-663a-1c1f-a638-830fff8d304d&GUID=&SMAUTHREASON=0&METHOD=GET&SMAGENTNAME=3JvzMJPnsWmtQqhUoIH1c1MAe19pZEARu1mcIUENVQ4TkH3TtYmnXFXW2CQ1eMot&TARGET=$SM$HTTPS%3a%2f%2ffederation%2emedtronic%2ecom%2fredirectjsp%2fredirect%2ejsp%3fSAMLRequest%3dlVNNk6IwEP0rVg57AwGnFNlRS8EPVFwFVGYuFmAEHEiQDiL$%2B$%2BkVdt2bnMFXbVTkk3Xkvr$%2FvltXdJ4toZZxBR0kEiL6AaJj7dRyTooLU94mTU676Cm8Sp0s9ZSEx8yjGwWnWPgHJPdFCeEYW6EIFC3ASDwnzF6htzReIFJc0ooz6NUa0PgDNWEamUQJ7gzMLZOfLx2px3UMhYCkq9nuA9yyiJfC6JWMAnJQ9ujOFAMx$%2FzPk16QDuCoK2FR8xmrEQ1rXpRRFx2F$%2FFEOuA9zu5n$%2FF$%2FQG0LdPRwK7MGDHOpp7sWRX79JkQBoz1rqWucJYuj22Bpp6g83SX8u$%2F0gZROTeoO9ke48aUCa2veSWvywb1SpctJPUfhXb9XrLYtcYyoUx1AtD69$%2BWsLp$%2BiLe0CG1zdrxMT8XcMctFuR$%2BvKA244OPa3sjS$%2BKyxhAGZFc2jtTHCIaXUcidjiTDTaq$%2FfD01JFkPpQk$%2FCftLcBeEo86l9igsyKoxFCU6ZkekMwomjelBwRjpN82bzuDBOg1CXHW6794$%2BaJ71wzWu2JfO3sIxWXOg75Qu2zG0rNbT5UNxpru9MZsehuvD8lixKIhEkSzy$%2FLA$%2BaPn73PKFBzd0iWK7kImFMbTXsRqAasG9mupMO39hgA$%2BNz6MBFNJg3nUykcJDT1N$%2Fg0jHbQdUtgBzrBJhLWAdJgihzQosTBVuUFKmliA2$%2B4nxHta9TQf87ls3T$%2FlUBephduZNnn1z$%2BPaz7tDbqfnXOa$%2F0TYPex$%2B$%2FcvdX8D%26RelayState%3d$%2F%26SigAlg%3dhttp$%3A$%2F$%2Fwww%2ew3%2eorg$%2F2000$%2F09$%2Fxmldsig$%23rsa-sha1%26Signature%3dnzcOLM0bq$%2BDml77N61q63gJ$%2FuXFSrLy7cZUzWhYwDufvgV3Di1Bt0qziyUGeLs$%2FznX9Z$%2FEDKkKmQKpYWGo$%2FL8z97aBiJR3lrMjbyzoIh$%2BNBF5vb2ViBNR4QsWRy4srtFIZWdbaOGlYtsDnv$%2FnNshWgxAmQ8h$%2B5hN2eTLyjWydu3sJ$%2FS65cxjolxIa51bkeOl5gPeNhLfpBEyyOTqk4hBS1zCl6gu3$%2Ft4Lzb2g$%2F4b$%2FBjhYCebrP$%2F$%2BfPgKCG3Xj$%2B91lcLA5sOPU063auVR2zvljMElcldiqID3zETg2hi7jkHiA0NeFoKbF1YP1ziXGdML4VmzsGjskpTI2wZBRK9P5g$%3D$%3D%26SPID%3dhttps$%3A$%2F$%2FMITGSFDC%26ProtocolBinding%3durn$%3Aoasis$%3Anames$%3Atc$%3ASAML$%3A2%2e0$%3Abindings$%3AHTTP-POST%26SMPORTALURL%3dhttps$%3A$%2F$%2Ffederation%2emedtronic%2ecom$%2Faffwebservices$%2Fpublic$%2Fsaml2sso%26SAMLTRANSACTIONID%3ddd278a00-1ea5e3ca-64eef434-249cce5f-65722005-3")
        driver.get('https://medtronic-mitg.my.salesforce.com')
        #print(username+password)
#         driver.find_element_by_xpath("/html/body/div[1]/div[1]/div/div/div[6]/button/span").click()
#         driver.find_element_by_name("USER").send_keys(username)
#         driver.find_element_by_name("PASSWORD").send_keys(password+Keys.RETURN)
        driver.find_element_by_id('username').send_keys(username)
        driver.find_element_by_id('password').send_keys(password+Keys.RETURN)
        
        """FROM CASES TO REPORT"""
        time.sleep(30)
        driver.switch_to_default_content()
        em = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(em,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()
        
        
        """ENTER VISHAL M: 4.1B IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        em.send_keys("Vishal M: 4.1B" + Keys.RETURN)

        time.sleep(5)
        """CLICK ON VISHAL M:4.1B HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 4.1B").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1013']")

        driver.switch_to_frame(em)

        #driver.switch_to_frame(driver.find_element_by_id("ext-comp-1024"))
        driver.find_element_by_link_text("Edit").click()

        "CLICK ON EDIT LINK AND PUTS START DATE"
        driver.find_element_by_id("ext-gen48").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("05/31/2018")
        driver.find_element_by_id("ext-gen838").click()

        "CLICK ON EDIT LINK AND PUTS END DATE"
        time.sleep(3)
        driver.find_element_by_id("ext-gen55").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("07/1/2018")
        em = driver.find_element_by_id("ext-gen838")
        em.click()

        """Run Report"""
        driver.find_element_by_id("ext-gen108").click()
        time.sleep(5)

        """Printable view"""
        driver.find_element_by_name("excel").click()


        # """Export Details"""
        # driver.find_element_by_name("csvsetup").click()

        # """Export Again"""
        # """Task is done"""
        # driver.find_element_by_name("export").click()


        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"4-1B.xls"))

        # 4.2 Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER VISHAL M: 4.2 IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("Vishal M: 4.2")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1B HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 4.2").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1018']")

        driver.switch_to_frame(em)

        #driver.switch_to_frame(driver.find_element_by_id("ext-comp-1024"))
        driver.find_element_by_link_text("Edit").click()

        "CLICK ON EDIT LINK AND PUTS START DATE"
        driver.find_element_by_id("ext-gen48").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("05/31/2018")
        driver.find_element_by_id("ext-gen800").click()

        "CLICK ON EDIT LINK AND PUTS END DATE"
        time.sleep(3)
        driver.find_element_by_id("ext-gen55").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("07/1/2018")
        em = driver.find_element_by_id("ext-gen800")
        em.click()

        """Run Report"""
        driver.find_element_by_id("ext-gen108").click()
        time.sleep(5)

        """Printable view"""
        driver.find_element_by_name("excel").click()



        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"4-2.xls"))

        # 4.1A Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER VISHAL M:4.1A IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("Vishal M:4.1A")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1A HYPERLINK"""
        driver.find_element_by_link_text("Vishal M:4.1A").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1023']")

        driver.switch_to_frame(em)

        el1 = driver.find_element_by_id("sdate")
        el1.clear()
        el1.send_keys("06/01/2018")

        el1 = driver.find_element_by_id("edate")
        el1.clear()
        el1.send_keys("06/30/2018")

        driver.find_element_by_id("runMuttonLabel").click()

        driver.find_element_by_name("csvsetup").click()

        driver.find_element_by_name("export").click()

        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"4-1A.xls"))

        # 5.3 Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER 5.3 New Rebate Process Time IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("5.3 New Rebate Process Time")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1A HYPERLINK"""
        driver.find_element_by_link_text("5.3 New Rebate Process Time").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1028']")

        driver.switch_to_frame(em)

        el1 = driver.find_element_by_id("sdate")
        el1.clear()
        el1.send_keys("06/01/2018")

        el1 = driver.find_element_by_id("edate")
        el1.clear()
        el1.send_keys("06/30/2018")

        driver.find_element_by_id("runMuttonLabel").click()

        driver.find_element_by_name("csvsetup").click()

        driver.find_element_by_name("export").click()

        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"5-3.xls"))

        # 5.4A Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER 5.3 New Rebate Process Time IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("Vishal M: 5.4A")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1A HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 5.4A").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1033']")

        driver.switch_to_frame(em)

        el1 = driver.find_element_by_id("sdate")
        el1.clear()
        el1.send_keys("06/01/2018")

        el1 = driver.find_element_by_id("edate")
        el1.clear()
        el1.send_keys("06/30/2018")

        driver.find_element_by_id("runMuttonLabel").click()

        driver.find_element_by_name("csvsetup").click()

        driver.find_element_by_name("export").click()

        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"5-4A.xls"))

        # 5.4B Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER 5.3 New Rebate Process Time IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("Vishal M: 5.4B")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1A HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 5.4B").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1038']")

        driver.switch_to_frame(em)

        el1 = driver.find_element_by_id("sdate")
        el1.clear()
        el1.send_keys("06/01/2018")

        el1 = driver.find_element_by_id("edate")
        el1.clear()
        el1.send_keys("06/30/2018")

        driver.find_element_by_id("runMuttonLabel").click()

        driver.find_element_by_name("csvsetup").click()

        driver.find_element_by_name("export").click()

        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"5-4B.xls"))

        # 5.5 Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER 5.3 New Rebate Process Time IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("5.5 Payment Lead Time")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1A HYPERLINK"""
        driver.find_element_by_link_text("5.5 Payment Lead Time").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1043']")

        driver.switch_to_frame(em)

        el1 = driver.find_element_by_id("sdate")
        el1.clear()
        el1.send_keys("06/01/2018")

        el1 = driver.find_element_by_id("edate")
        el1.clear()
        el1.send_keys("06/30/2018")

        driver.find_element_by_id("runMuttonLabel").click()

        driver.find_element_by_name("csvsetup").click()

        driver.find_element_by_name("export").click()

        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"5-5.xls"))

        # 4.3A Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER VISHAL M: 4.1B IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        time.sleep(2)
        em.send_keys("Vishal M: 4.3A")

        time.sleep(5)
        """CLICK ON VISHAL M:4.1B HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 4.3A").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1048']")

        driver.switch_to_frame(em)

        #driver.switch_to_frame(driver.find_element_by_id("ext-comp-1024"))
        driver.find_element_by_link_text("Edit").click()

        "CLICK ON EDIT LINK AND PUTS START DATE"
        driver.find_element_by_id("ext-gen48").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("05/31/2018")
        driver.find_element_by_id("ext-gen812").click()

        "CLICK ON EDIT LINK AND PUTS END DATE"
        time.sleep(3)
        driver.find_element_by_id("ext-gen55").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("07/1/2018")
        em = driver.find_element_by_id("ext-gen812")
        em.click()

        """Run Report"""
        driver.find_element_by_id("ext-gen115").click()
        time.sleep(5)

        """Printable view"""
        driver.find_element_by_name("csvsetup").click()


        # """Export Details"""
        # driver.find_element_by_name("csvsetup").click()

        # """Export Again"""
        # """Task is done"""
        # driver.find_element_by_name("export").click()


        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"4-3A.xls"))

        # 4.3B Download!

        """FROM CASES TO REPORT"""
        driver.switch_to_default_content()
        el = driver.find_element_by_id("ext-gen33")
        action = ActionChains(driver)
        action.move_to_element_with_offset(el,237,5).click().perform()
        driver.find_element_by_id("nav-tab-4").click()

        """ENTER VISHAL M: 4.1B IN SEARCH BOX"""
        driver.switch_to_default_content()
        driver.switch_to_frame(driver.find_element_by_id("ext-comp-1005"))
        em = driver.find_element_by_id("ext-comp-1013")
        em.clear()
        em.send_keys("Vishal M: 4.3B" + Keys.RETURN)

        time.sleep(5)
        """CLICK ON VISHAL M:4.1B HYPERLINK"""
        driver.find_element_by_link_text("Vishal M: 4.3B").click()

        """SWITCHING TO NEW FRAME AND CLICKING ON EDIT LINK"""

        driver.switch_to_default_content()
        #em = driver.find_element_by_id("ext-comp-1024")
        em = driver.find_element_by_xpath("//*[@id='ext-comp-1053']")

        driver.switch_to_frame(em)

        #driver.switch_to_frame(driver.find_element_by_id("ext-comp-1024"))
        driver.find_element_by_link_text("Edit").click()

        "CLICK ON EDIT LINK AND PUTS START DATE"
        driver.find_element_by_id("ext-gen48").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("05/31/2018")
        driver.find_element_by_id("ext-gen812").click()

        "CLICK ON EDIT LINK AND PUTS END DATE"
        time.sleep(3)
        driver.find_element_by_id("ext-gen55").click()
        datefield = driver.find_element_by_name("pv")
        datefield.clear()
        datefield.send_keys("07/1/2018")
        em = driver.find_element_by_id("ext-gen812")
        em.click()

        """Run Report"""
        driver.find_element_by_id("ext-gen115").click()
        time.sleep(5)

        """Printable view"""
        driver.find_element_by_name("csvsetup").click()


        # """Export Details"""
        # driver.find_element_by_name("csvsetup").click()

        # """Export Again"""
        # """Task is done"""
        # driver.find_element_by_name("export").click()


        time.sleep(5)
        list_of_files = glob.glob("D:\\Users\\703207054\\Downloads\\*") 
        latest_file = max(list_of_files, key=os.path.getctime)

        os.renames(latest_file,("D:\\Users\\703207054\\Downloads\\SFDC KPI\\"+"4-3B.xls"))


#         #print("lag gaye 440 volt se chone se tere lag gaye ")
#         print("tu jaha jaha rahegea"+username+"tera saaya saath hoga"+password+"tu jaha jaha rahega")


# class otpframe(Frame):
#     def __init__(self, master):
#         super().__init__(master)
#         self.label_otp = Label(self,text ="OTP")
#         self.entry_otp = Entry(self)
#         self.label_otp.grid(row=4,sticky =E)
#         self.entry_otp.grid(row=4, column =1)
        
#         self.otpbtn = Button(self, text="OTP", command=self._otp_btn_clicked)
#         self.otpbtn.grid(columnspan=2)
# #     self.label_otp = Label(self,text ="OTP")
# #     self.entry_otp = Entry(self)
# #     self.label_otp.grid(row=4,sticky =E)
# #     self.entry_otp.grid(row=4, column =1)
    
        


#     def _otp_btn_clicked(self):
#         otp = self.entry_otp.get()
#         driver.find_element_by_name('smc').send_keys(otp)
#         driver.find_element_by_name('Save').click()     
        
        
        
root = Tk()
lf = LoginFrame(root)

root.mainloop()

# %%
import tkinter as tk                # python 3
from tkinter import font  as tkfont # python 3
#import Tkinter as tk     # python 2
#import tkFont as tkfont  # python 2

class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")

        # the container is where we'll stack a bunch of frames
        # on top of each other, then the one we want visible
        # will be raised above the others
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            # put all of the pages in the same location;
            # the one on the top of the stacking order
            # will be the one that is visible.
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()


class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is the start page", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)

        button1 = tk.Button(self, text="Go to Page One",
                            command=lambda: controller.show_frame("PageOne"))
        button2 = tk.Button(self, text="Go to Page Two",
                            command=lambda: controller.show_frame("PageTwo"))
        button1.pack()
        button2.pack()


class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 1", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 2", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()

# %%
import bokeh

# %%
import pandas as pd
df = pd.read_csv("D:\\Users\\703183779\\Documents\\Mounika\\AAAD_Eligibility.csv",index_col=0)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-6518fbc70aeb> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("D:\\Users\\703183779\\Documents\\Mounika\\AAAD_Eligibility.csv",index_col=0)
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel(r"D:\Users\703183779\Documents\AAAD details-Subject.xlsx",index_col=None)
df.head()
df.columns
# Out:
# Index(['UserDepartment', 'MailFrom', 'Flag', 'OriginalSubject', 'LastName',
#        'FirstName', 'ArrivalTime', 'OpenTime', 'ClosedTime', 'OpenDuration',
#        'Name', 'ID', 'TextValue'],
#       dtype='object')

# %%
data = list(df.UserDepartment)

# %%
subject = list(df.OriginalSubject)

# %%
import pandas as pd

df=pd.read_excel(r"D:\Users\703183779\Documents\AAAD details-Subject.xlsx",index_col=None)
data = list(df.UserDepartment)
""" Convert subject to list"""
subject = list(df.OriginalSubject)

# create an empty list

contract_name =[]

for i in subject:
    if any(word in i for word in ['Eligibility','Rebate inquiry','item','CUSTOMER',
                               'Expiration','GPO Change Notification',
                                  'MEDICAL CENTER','ELIGIBILITY','eligibility','CHANGE','elig','Elig','Eligiblity','eligibity','ELIGIBLITY']):
        #df['Contract Name'] = df['Contract Name'].append("Contract Eligibility")
        contract_name.append('Eligibility')
    elif any(word in i for word in ['Pricing','PRICING','pricing']):
        contract_name.append('Pricing')
    elif any(word in i for word in ['Approval','Approvals']):
        contract_name.append('Approval')
    elif any(word in i for word in ['Refresh','Option','Contract','Contracts','contract','CONTRACT']): 
        contract_name.append('Contract Refresh')
    elif any(word in i for word in ['Refresh','Option']): 
        contract_name.append('Contract Refresh')
    elif any(word in i for word in ['discrepancy','Discrepancy']): 
        contract_name.append('Sequence of Contract')  
    elif any(word in i for word in ['Notification','notification']):
        contract_name.append('Notification')
    elif any(word in i for word in ['SURGICAL','Surgical','SURG']):
        contract_name.append('SURGICAL')
    elif any(word in i for word in ['Auto Response']):
        contract_name.append('Auto Response')
    elif any(word in i for word in ['KENDALL']):
        contract_name.append('KENDALL')
    elif any(word in i for word in ['Incident','Update','Task']):
        contract_name.append('Incident')
    elif any(word in i for word in ['New']):
        contract_name.append('New Customer')    
    else:
        contract_name.append('Other')
        #df['Contract Name'] = df['Contract Name'].append("other")
df['Contract Category'] = contract_name

#Exporting data to csv file
#df.to_csv(r'D:\Users\703183779\Documents\Mounika\AAAD_WITH_CONTRACT_CATEGORY_NAME_V1.csv',sep=",")
#MEDLINE'
""" CARDINAL,McKesson,OWENS & MINORS,MEDLINE"""
# Out:
# ' CARDINAL,McKesson,OWENS & MINORS,MEDLINE'

# %%
df.head()
# Out:
#             UserDepartment              MailFrom     Flag  \
# 0  Genpact Group Contracts  Div17CnR@medline.com  Medline
# 1  Genpact Group Contracts  ASantera@medline.com  Medline
# 2  Genpact Group Contracts  ASantera@medline.com  Medline
# 3  Genpact Group Contracts  ASantera@medline.com  Medline
# 4  Genpact Group Contracts  ASantera@medline.com  Medline
#
#                                      OriginalSubject LastName FirstName  \
# 0  *Second Request* - FW: [EXTERNAL] *Second Requ...   Thakur     Megha
# 1  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Zaheer      Uzma
# 2  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Zaheer      Uzma
# 3  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Thakur     Megha
# 4  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...    Punna   Mounika
#
#           ArrivalTime            OpenTime          ClosedTime  OpenDuration  \
# 0 2018-01-15 09:57:03 2018-01-18 05:52:36 2018-01-18 05:53:50          74.0
# ...

# %%
if __name__=='__main__':
    df[df['OpenDuration'][df['Contract Category']=='Eligibility']>400]
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-366-cd258c0386e1> in <module>()
#       1
#       2 if __name__=='__main__':
# ----> 3     df[df['OpenDuration'][df['Contract Category']=='Eligibility']>400]
#       4
#       5
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# ...

# %%
Elig_Count=sum(df['Contract Category'].str.count('Other'))
Elig_Count
# Out:
# 709

# %%
def category_count(x):
    return sum(df['Contract Category'].str.count(x))

# %%
Cat_Count=map(lambda x: category_count(x), ['Eligibility','Pricing','Approval','Contract Refresh','Sequence of Contract','Notification','SURGICAL','Auto Response','KENDALL','Incident','New Customer','Other'])

# [Elig_Count, Pricing_Count, Approval_Count, CR_Count, SoC_Count,N_Count,Surg_Count,Auto_Count,KENDALL,Incident, New Customer, Other_Count]

#print(list(Cat_Count))

[a,b,c,d,e,f,g,h,i,j,k,l] = list(Cat_Count)

m=[a,b,c,d,e,f,g,h,i,j,k,l]

# %%
categories =['Elig', 'Pric', 'App', 'CR', 'SoC','Noti','SUR','Aut','KEND','Inc',
              'NW','Other']
d ={}
for ind,val in enumerate(m):
    for ind1,val1 in enumerate(categories):
        if(ind==ind1):
            d.update({val1:val})
        
d
# Out:
# {'App': 2,
#  'Aut': 218,
#  'CR': 419,
#  'Elig': 1926,
#  'Inc': 803,
#  'KEND': 120,
#  'NW': 225,
#  'Noti': 90,
#  'Other': 709,
#  'Pric': 226,
#  'SUR': 272,
#  'SoC': 3}

# %%
import operator

sorted_d = sorted(d.items(), key=operator.itemgetter(1))
sorted_d
# categories = []
# val =[]
# for i in sorted_d:
#     categories.append(i[0])
#     val.append(i[1])
# Out:
# [('App', 2),
#  ('SoC', 3),
#  ('Noti', 90),
#  ('KEND', 120),
#  ('Aut', 218),
#  ('NW', 225),
#  ('Pric', 226),
#  ('SUR', 272),
#  ('CR', 419),
#  ('Other', 709),
#  ('Inc', 803),
#  ('Elig', 1926)]

# %%
categories = []
val =[]
for i in sorted_d:
    categories.append(i[0])
    val.append(i[1])

# %%
print(categories,val)
# Out:
# ['App', 'SoC', 'Noti', 'KEND', 'Aut', 'NW', 'Pric', 'SUR', 'CR', 'Other', 'Inc', 'Elig'] [2, 3, 90, 120, 218, 225, 226, 272, 419, 709, 803, 1926]

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
label =['Approval','Sequence of Contract','Notification','KENDALL','Auto Response','New Customer',
       'Pricing','SURGICAL','Contract Refresh','Other','Incident','ELIGIBILITY']
# Categories = ('Elig', 'Pric', 'App', 'CR', 'SoC','Noti','SUR','Aut','KEND','Inc',
#               'NW','Other')
# high = max(m)
# low = min(m)
bar_plot=plt.bar(np.arange(len(val)),val,width =0.5,align ='center',color = ['black', 'red', 'green', 'blue', 'orange','purple',
                                                                'yellow','Pink','brown','grey'])
#label= ['Eligibility','Pricing','Approval','Contract Refresh','Sequence of Contract','Notification','SURGICAL','Auto Response','KENDALL','Incident','New Customer','Other']
plt.xticks(np.arange(len(val)), categories)
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.ylabel('Volume of Items')
plt.xlabel('AAAD Category Name')
plt.title('Count of AAAD Category')
plt.legend([bar for bar in bar_plot],label,loc=2,fontsize ='xx-small')
#plt.figure(figsize =(4,5))
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Category_figure.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %%
Incident_df=df[df['Contract Category']=='Incident']

Incident_df.to_csv(r"D:\Users\703183779\Documents\Mounika\Incident.csv",sep=",")

# %%
Incident_df.columns
# Out:
# Index(['UserDepartment', 'MailFrom', 'Flag', 'OriginalSubject', 'LastName',
#        'FirstName', 'ArrivalTime', 'OpenTime', 'ClosedTime', 'OpenDuration',
#        'Name', 'ID', 'TextValue', 'Contract Category'],
#       dtype='object')

# %%
inc_subject=list(Incident_df['OriginalSubject'])

# %%
import re
##pattern = 'MS[a-z,A-Z,0-9]{4} | CS[a-z,A-Z,0-9]{4}'
pattern =  'MS[a-z,A-Z,0-9]{4}'
pattern = re.compile(pattern)
l=[]
for i in inc_subject:
    k=re.findall(pattern,i)
    if(len(k)>0):
        l.append(k)
# Out:
# [['MS2970'],
#  ['MS1285'],
#  ['MSPDBS'],
#  ['MS4501'],
#  ['MS6231'],
#  ['MSPDB1'],
#  ['MS5351'],
#  ['MS1007'],
#  ['MS5341', 'MS5351'],
#  ['MS1583'],
#  ['MSPDB1'],
#  ['MS2794', 'MS1285'],
#  ['MS1136'],
#  ['MSR048'],
#  ['MS0298'],
#  ['MS0681'],
#  ['MS5341'],
#  ['MS0681'],
#  ['MS3133'],
#  ['MS3021'],
#  ['MS4480'],
#  ['MS6231'],
#  ['MSPDBS'],
#  ['MS5351'],
#  ['MS5441'],
#  ['MS5251'],
#  ['MS5351'],
#  ['MS0389'],
#  ['MS0282'],
#  ['MS0297'],
#  ['MS5341', 'MS5351'],
#  ['MSPDBS'],
#  ['MS2980']]

# %%
a =[]
for i in l:
    for j in i:
        m="".join(j.split())
        a.append(m)

# %%
Vizient_cont_list =list(set(a))

# %%
def find_pattern(subject,pattern):
    pattern = re.compile(pattern)
    l=[]
    for i in subject:
        k=re.findall(pattern,i)
        if(len(k)>0):
            l.append(k)
    a =[]
    for i in l:
        for j in i:
            m="".join(j.split())
            a.append(m)
    return a

# %%
Premier_cnt_list = find_pattern(inc_subject,'PP-[a-z|A-Z|0-9]{2}-[a-z|A-Z|0-9]{4}')
Premier_cnt_list
# Out:
# ['PP-OR-1478',
#  'PP-OR-1218',
#  'PP-OR-1218',
#  'PP-OR-1218',
#  'PP-OR-1233',
#  'PP-OR-1249',
#  'PP-NS-1067']

# %%
Vizient_cnt_list = find_pattern(inc_subject,'MS[a-z|A-Z|0-9]{4}|CE[a-z|A-Z|0-9]{4}')
Vizient_cnt_list
# Out:
# ['CE3002',
#  'MS2970',
#  'MS1285',
#  'MSPDBS',
#  'MS4501',
#  'MS6231',
#  'MSPDB1',
#  'MS5351',
#  'MS1007',
#  'MS5341',
#  'MS5351',
#  'MS1583',
#  'MSPDB1',
#  'CE0332',
#  'MS2794',
#  'MS1285',
#  'MS1136',
#  'MSR048',
#  'MS0298',
#  'MS0681',
#  'MS5341',
#  'MS0681',
#  'MS3133',
#  'CE2981',
#  'CE2990',
#  'MS3021',
#  'MS4480',
#  'MS6231',
#  'MSPDBS',
#  'MS5351',
#  'MS5441',
#  'MS5251',
#  'CENTRA',
#  'CEIVIN',
#  'MS5351',
#  'MS0389',
#  'MS0282',
#  'MS0297',
#  'MS5341',
#  'MS5351',
#  'MSPDBS',
#  'MS2980']

# %%
Amerinet = find_pattern(inc_subject,'VH|VQ|CB')
Amerinet
# Out:
# ['VH', 'VH', 'CB', 'CB']

# %%
ROI = find_pattern(inc_subject,'RMS|RCE|RPL')
ROI
# Out:
# ['RPL']

# %%
eligibility_name =[]

for i in inc_subject:
    if any(word in i for word in ['item','customer','ITEM','CUSTOMER','Item','Customer']):
        #df['Contract Name'] = df['Contract Name'].append("Contract Eligibility")
        eligibility_name.append('ITEM Eligibility')
    elif any(word in i for word in Vizient_cnt_list):
        eligibility_name.append('Vizient Contract Eligibility')
    elif any(word in i for word in Premier_cnt_list):
        eligibility_name.append('Premier Contract Eligibility')
    elif any(word in i for word in ['VH','VQ','CB']): 
        eligibility_name.append('Amerinet')
    elif any(word in i for word in ['RMS','RCE','RPL']): 
        eligibility_name.append('ROI')  
    else:
        eligibility_name.append('Other')
        #df['Contract Name'] = df['Contract Name'].append("other")
Incident_df['Eligibility'] = eligibility_name
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Incident_df.columns
# Out:
# Index(['UserDepartment', 'MailFrom', 'Flag', 'OriginalSubject', 'LastName',
#        'FirstName', 'ArrivalTime', 'OpenTime', 'ClosedTime', 'OpenDuration',
#        'Name', 'ID', 'TextValue', 'Contract Category', 'Eligbility',
#        'Eligibility'],
#       dtype='object')

# %%
#df.drop(columns=['B', 'C'])
del Incident_df['Eligbility']
Incident_df
# Out:
#                UserDepartment                         MailFrom      Flag  \
# 2363  Genpact Group Contracts              BLJones@medline.com   Medline
# 2369  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2372  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2375  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2376  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2380  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2381  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2382  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2384  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2387  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2388  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# 2390  Genpact Group Contracts   DistributedPricing@medline.com   Medline
# ...

# %%
Incident_df['OriginalSubject'][Incident_df['Eligibility']=='Other']
# Out:
# 2363    [EXTERNAL] FW: Incident# 1293891 G2597 COVIDIE...
# 2372    [EXTERNAL] FW: Incident# 1328228 RE: DSM PRICE...
# 2375    [EXTERNAL] FW: Incident# 1335192 RE: Regen Med...
# 2376    [EXTERNAL] FW: Incident# 1339720 RE: MEDLINE P...
# 2380     [EXTERNAL] FW: Incident# 1347899 G3154 COVIDIEN
# 2381    [EXTERNAL] FW: Incident# 1349637 RE: Account #...
# 2382    [EXTERNAL] FW: Incident# 1358647 RE: WATERBURY...
# 2384           [EXTERNAL] FW: Incident# 1381957 RE: Telfa
# 2387    [EXTERNAL] FW: Incident# 1403589  FW: 1014276 ...
# 2390    [EXTERNAL] FW: Incident# 1420114 RE: G7208_201...
# 2394    [EXTERNAL] FW: Incident# 1455518 RE: Holyoke  ...
# 2398    [EXTERNAL] FW: Incident# 1470534 RE: [ Externa...
# 2399    [EXTERNAL] FW: Incident# 1472500 RE: Eye Surge...
# 2400    [EXTERNAL] FW: Incident# 1472749  FW: G1515 pr...
# 2402             [EXTERNAL] FW: Incident# 1480330 RE: PCN
# 2454          [EXTERNAL] FW: Update For Incident# 1311988
# ...

# %%
k=Incident_df[['OriginalSubject']][Incident_df['Eligibility']=='Other']
k.to_csv(r'D:\Users\703183779\Documents\Mounika\Incident_eligbility_type_other.csv',sep=",")

# %%
def category_count(x):
    return sum(Incident_df['Eligibility'].str.count(x))

Cat_Count=map(lambda x: category_count(x), ['ITEM Eligibility','Vizient Contract Eligibility','Premier Contract Eligibility','Amerinet','ROI','Other'])

# [Elig_Count, Pricing_Count, Approval_Count, CR_Count, SoC_Count,N_Count,Surg_Count,Auto_Count,KENDALL,Incident, New Customer, Other_Count]

#print(list(Cat_Count))

[a,b,c,d,e,f] = list(Cat_Count)

m=[a,b,c,d,e,f]    

categories =['Item', 'Vizient', 'Premier', 'Amerinet', 'ROI','Other']

d ={}

for ind,val in enumerate(m):
    for ind1,val1 in enumerate(categories):
        if(ind==ind1):
            d.update({val1:val})
            
import operator

sorted_d = sorted(d.items(), key=operator.itemgetter(1))
sorted_d
categories = []
val =[]
for i in sorted_d:
    categories.append(i[0])
    val.append(i[1])
print(categories,val)
# Out:
# ['ROI', 'Amerinet', 'Premier', 'Vizient', 'Item', 'Other'] [1, 4, 7, 30, 68, 693]

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
label =['ROI','Amerinet','Premier','Vizinet','Item','Other']
# Categories = ('Elig', 'Pric', 'App', 'CR', 'SoC','Noti','SUR','Aut','KEND','Inc',
#               'NW','Other')
# high = max(m)
# low = min(m)
bar_plot=plt.bar(np.arange(len(val)),val,width =0.5,align ='center',color = ['black', 'red', 'green', 'blue', 'orange','purple'])
#label= ['Eligibility','Pricing','Approval','Contract Refresh','Sequence of Contract','Notification','SURGICAL','Auto Response','KENDALL','Incident','New Customer','Other']
plt.xticks(np.arange(len(val)), categories)
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.ylabel('Volume of Items')
plt.xlabel('Incident Eligbility Name')
plt.title('Incident Eligibility Type')
plt.legend([bar for bar in bar_plot],label,loc=2,fontsize ='xx-small')
#plt.figure(figsize =(4,5))
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Incident_eligbility_type.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %%
I_g400 = Incident_df[Incident_df['OpenDuration']>400]

I_g400
# Out:
#                UserDepartment                         MailFrom     Flag  \
# 2376  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2380  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2387  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2388  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2402  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2595  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2606  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2621  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2630  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2641  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2644  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# 2669  Genpact Group Contracts   DistributedPricing@medline.com  Medline
# ...

# %%
I_g400.to_csv(r'D:\Users\703183779\Documents\Mounika\I_g400.csv',sep=",")

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
Categories = ('Elig', 'Pric', 'App', 'CR', 'SoC','Noti','SUR','Aut','KEND','Inc',
              'NW','Other')
# high = max(m)
# low = min(m)
bar_plot=plt.bar(np.arange(len(m)),m,width =0.5,align ='center',color = ['black', 'red', 'green', 'blue', 'orange','purple',
                                                                'yellow','Pink','brown','grey'])
label= ['Eligibility','Pricing','Approval','Contract Refresh','Sequence of Contract','Notification','SURGICAL','Auto Response','KENDALL','Incident','New Customer','Other']
plt.xticks(np.arange(len(m)), Categories)
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.ylabel('Volume of Items')
plt.xlabel('AAAD Category Name')
plt.title('Count of AAAD Category')
plt.legend([bar for bar in bar_plot],label,loc=1,fontsize ='xx-small')
#plt.figure(figsize =(4,5))
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Category_figure.JPEG',dpi=400,orientation='landscape',figsize =(6,6))
plt.show()

# %%
df.columns
# Out:
# Index(['UserDepartment', 'MailFrom', 'Flag', 'OriginalSubject', 'LastName',
#        'FirstName', 'ArrivalTime', 'OpenTime', 'ClosedTime', 'OpenDuration',
#        'Name', 'ID', 'TextValue', 'Contract Category'],
#       dtype='object')

# %%
eligibility_df=df[df['Contract Category']=='Eligibility']
eligibility_df.to_csv(r'D:\Users\703183779\Documents\Mounika\Eligibility DataFrame.csv',sep=",")


GPO=N_df['OpenDuration'][N_df['Elig_Cat']=='GPO']
GPO = list(GPO)

GPO
plt.scatter(range(len(GPO)),GPO,color ='orange')
plt.title("Scatter plot of GPO data with OpenDuration")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\GPO_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('GPO')
plt.show()
print(pd.DataFrame(GPO).describe())

plt.boxplot(GPO,vert=False)
plt.xlabel("Time taken in minutes")
plt.title("Box plot of GPO Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\GPO_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()

# %%
time_g400=eligibility_df[eligibility_df['OpenDuration']>400]
time_g400.to_csv(r"D:\Users\703183779\Documents\Mounika\time_g400.csv",sep=",")

# %%
Medline=eligibility_df['OpenDuration'][eligibility_df['Flag']=='Medline']
Medline.fillna(method='pad')
Medline=list(Medline[Medline<800])
plt.scatter(range(len(Medline)),Medline,color ='red')
plt.title("Scatter plot of Medline data with OpenDuration < 800 seconds")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('Medline')
plt.show()
print(pd.DataFrame(Medline).describe())

plt.boxplot(Medline,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of Medline Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count  576.000000
# mean   156.368056
# std    148.459885
# min      5.000000
# 25%     62.000000
# 50%    106.000000
# 75%    199.750000
# max    776.000000

# %%
Medline=eligibility_df['OpenDuration'][eligibility_df['Flag']=='Medline']
Medline.fillna(method='pad')
Medline=list(Medline[Medline>400])
plt.scatter(range(len(Medline)),Medline,color ='red')
plt.title("Scatter plot of Medline data with OpenDuration > 400 seconds")
plt.ylabel("Time Duration")
plt.ylim([0,10000])
plt.yticks(np.arange(0,10000,500))
#plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('Medline')
plt.show()
print(pd.DataFrame(Medline).describe())

plt.boxplot(Medline,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of Medline Data")
#plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                   0
# count     61.000000
# mean    1870.147541
# std     8912.625288
# min      401.000000
# 25%      461.000000
# 50%      593.000000
# 75%      729.000000
# max    70175.000000

# %%
McKesson=eligibility_df['OpenDuration'][eligibility_df['Flag']=='McKesson']
McKesson.fillna(method='pad')
McKesson=list(McKesson[McKesson<800])
plt.scatter(range(len(McKesson)),McKesson,color ='red')
plt.title("Scatter plot of McKesson data with OpenDuration < 800 seconds")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\McKesson_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('McKesson')
plt.show()
print(pd.DataFrame(Mckesson).describe())

plt.boxplot(Medline,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of McKesson Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\McKesson_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#        OpenDuration
# count    668.000000
# mean     130.034431
# std      193.386324
# min        4.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max     3187.000000
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)

# %%
Cardinal=eligibility_df['OpenDuration'][eligibility_df['Flag']=='Cardinal']
Cardinal.fillna(method='pad')
Cardinal=list(Cardinal[Cardinal<800])
plt.scatter(range(len(Cardinal)),Cardinal,color ='red')
plt.title("Scatter plot of Cardinal data with OpenDuration < 800 seconds")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Cardinal_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('Cardinal')
plt.show()
print(pd.DataFrame(Cardinal).describe())

plt.boxplot(Cardinal,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of Cardinal Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Cardinal_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count  311.000000
# mean   100.186495
# std    110.360570
# min      4.000000
# 25%     26.500000
# 50%     62.000000
# 75%    137.500000
# max    628.000000

# %%
OW=eligibility_df['OpenDuration'][eligibility_df['Flag']=='Owens & Minor']
OW.fillna(method='pad')
OW=list(OW[OW<800])
plt.scatter(range(len(OW)),OW,color ='red')
plt.title("Scatter plot of Owens & Minor data with OpenDuration < 800 seconds")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\OW_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('Cardinal')
plt.show()
print(pd.DataFrame(OW).describe())

plt.boxplot(OW,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of Owens & Minor Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\OW_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count   46.000000
# mean   184.130435
# std    156.954432
# min      8.000000
# 25%     81.750000
# 50%    139.000000
# 75%    242.250000
# max    697.000000

# %%
OT=eligibility_df['OpenDuration'][eligibility_df['Flag']=='Others']
OT.fillna(method='pad')
OT=list(OT[OT<800])
plt.scatter(range(len(OT)),OT,color ='red')
plt.title("Scatter plot of Others data with OpenDuration < 800 seconds")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\OT_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('Others')
plt.show()
print(pd.DataFrame(OW).describe())

plt.boxplot(Other,vert=False)
plt.xlabel("Time taken in seconds")
plt.title("Box plot of Other Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\OT_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count   46.000000
# mean   184.130435
# std    156.954432
# min      8.000000
# 25%     81.750000
# 50%    139.000000
# 75%    242.250000
# max    697.000000

# %%
Flag = list(eligibility_df.Flag)
# Out:
# ['Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Owens & Minor',
#  'Medline',
#  'McKesson',
#  'McKesson',
#  'Medline',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Cardinal',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'McKesson',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Cardinal',
#  'Medline',
#  'Medline',
#  'Medline',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Cardinal',
#  'Medline',
#  'Medline',
#  'Medline',
# ...

# %%
Med_count = Flag.count('Medline')
Cad_Count = Flag.count('Cardinal')
Mck_Count = Flag.count('McKesson')
Other_Count = Flag.count('Others')
Owens_Count = Flag.count('Owens & Minor')

# %%
categories =['Med','Car','McK','Oth','Owe']

m =[Med_count,Cad_Count,Mck_Count,Other_Count,Owens_Count]



d ={}
for ind,val in enumerate(m):
    for ind1,val1 in enumerate(categories):
        if(ind==ind1):
            d.update({val1:val})

sorted_d = sorted(d.items(), key=operator.itemgetter(1))
categories = []
val =[]
for i in sorted_d:
    categories.append(i[0])
    val.append(i[1])

# %%
sorted_d
# Out:
# [('Owe', 58), ('Oth', 165), ('Car', 346), ('Med', 651), ('McK', 706)]

# %%
labels=['OWENS & MINOR','OTHER','CARDINAL','MEDLINE','MCKESSON']
bar_plot=plt.bar(np.arange(len(val)),val,width =0.3,align ='center',color = ['red', 'black', 'yellow', 'orange', 'green'])

plt.legend([bar for bar in bar_plot],labels,fontsize='xx-small',loc=2)
plt.title("Eligibility Category basis of Flag")
plt.ylabel("Volume of items")
plt.xlabel("Eligibility Category")
plt.xticks(np.arange(len(val)),categories)
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Eligibility_figure_barplot_1.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %%
# Medline=eligibility_df['OpenDuration'][[elgibility_df['Flag']=='Medline']]

# %%
Incident_df=df[df['Contract Category']=='Eligibility']
Incident_df.to_csv(r'D:\Users\703183779\Documents\Mounika\Incident DataFrame.csv',sep=",")

# %%
OD_time=df['OpenDuration'][df['Contract Category']=='Eligibility']
Subject_line = df['OriginalSubject'][df['Contract Category']=='Eligibility']
Subject_line
# Out:
# 0       *Second Request* - FW: [EXTERNAL] *Second Requ...
# 1       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 2       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 3       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 4       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 5       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 6       [EXTERNAL] * nbr * Rebate inquiry to KENDALL H...
# 7       [EXTERNAL] **GHX 5.22.18** UNITYPOINT HEALTH -...
# 8       [EXTERNAL] *Second Request* - Contract Eligibi...
# 9       [EXTERNAL] *URGENT* MCKESSON PREMIER NEW CUSTO...
# 10      [EXTERNAL] *Urgent* MedAssets Contract Expirat...
# 11      [EXTERNAL] : Rebate inquiry to COVIDIEN RESPIR...
# 12      [EXTERNAL] [KD] Contract Eligibility Request -...
# 13      [EXTERNAL] [KD] GPO Change Notification - CROS...
# 14      [EXTERNAL] [KD] GPO Change Notification - Inno...
# 15      [EXTERNAL] [KD] GPO Change Notification - MedA...
# ...

# %% [markdown]
# ### Type of Eligibility query

# %%
Elig_Subject_line =pd.DataFrame(Subject_line)

# %%
Elig_Subject_line_list=list(Elig_Subject_line.OriginalSubject)
Elig_Subject_line_list
# Out:
# ['*Second Request* - FW: [EXTERNAL] *Second Request* - Contract Eligibility - CREEKSIDE CARE CENTER - SWD  {7019310}',
#  '[EXTERNAL] * NBR * Rebate inquiry to COVIDIEN                            (1282)  for Medline Customers 1041251. ',
#  '[EXTERNAL] * NBR * Rebate inquiry to COVIDIEN                            (1282)  for Medline Customers 1291059. ',
#  '[EXTERNAL] * NBR * Rebate inquiry to COVIDIEN (KENDALL)                  (145030)  for Medline Customers 1011102. ',
#  '[EXTERNAL] * NBR * Rebate inquiry to COVIDIEN (KENDALL)                  (145030)  for Medline Customers 1018526. ',
#  '[EXTERNAL] * NBR * Rebate inquiry to COVIDIEN (KENDALL)                  (145030)  for Medline Customers 1177716. ',
#  '[EXTERNAL] * nbr * Rebate inquiry to KENDALL HEALTHCARE PRODUCTS CO      (90134)  for Medline Customers 1002387. ',
#  '[EXTERNAL] **GHX 5.22.18** UNITYPOINT HEALTH - ALLEN HOSPITAL/item # 31140125',
# ...

# %%
eligibility_type =[]

for i in Elig_Subject_line_list:
    if any(word in i for word in ['Contract Eligibility','CONTRACT ELIGIBILITY','Contract','contract','CONTRACT']):
        #df['Contract Name'] = df['Contract Name'].append("Contract Eligibility")
        eligibility_type.append('CONTRACT')
    elif any(word in i for word in ['item','ITEM','Item Eligibility','Item']):
        eligibility_type.append('ITEM')
    elif any(word in i for word in ['Customer Eligibility','Customer Elig','CUSTOMER','Customer','customer']):
        eligibility_type.append('CUSTOMER')
    elif any(word in i for word in ['eligibility request','ELIGIBLITY REQUEST','Eligiblity Request','Eligibility request','ELIGIBILITY REQUEST','Eligibility Request','Request for Eligibility','REQUEST FOR Eligibility','REQUEST']): 
        eligibility_type.append('REQUEST')
    elif any(word in i for word in ['ACCOUNT Eligibility','account','Account']): 
        eligibility_type.append('ACCOUNT')
    elif any(word in i for word in ['Eligibility Inquiry','INQUIRY','ELIGIBILIITY INQUIRY','inquiry','Inquiry']): 
        eligibility_type.append('INQUIRY')  
    else:
        eligibility_type.append('Other')
        #df['Contract Name'] = df['Contract Name'].append("other")
Elig_Subject_line['ELIGIBILITY TYPE'] = eligibility_type

#Exporting data to csv file
Elig_Subject_line.to_csv(r'D:\Users\703183779\Documents\Mounika\AAAD_WITH_Eligibility_type.csv',sep=",")
#MEDLINE'

# %%
categories =['CO','IT','CU','RE','AC','IN','Other']
d ={}
for ind,val in enumerate(m):
    for ind1,val1 in enumerate(categories):
        if(ind==ind1):
            d.update({val1:val})
        
d
# Out:
# {'AC': 5, 'CO': 617, 'CU': 194, 'IN': 265, 'IT': 53, 'Other': 242, 'RE': 550}

# %%
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
sorted_d
categories = []
val =[]
for i in sorted_d:
    categories.append(i[0])
    val.append(i[1])
categories
# Out:
# ['AC', 'IT', 'CU', 'Other', 'IN', 'RE', 'CO']

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
#Categories = ('CO','IT','CU','RE','AC','IN','Other')
# high = max(m)
# low = min(m)
bar_plot=plt.bar(np.arange(len(val)),val,width =0.5,align ='center',color = ['black', 'red', 'green', 'blue', 'orange','purple',
                                                                'brown'])
plt.xticks(np.arange(len(val)), categories)
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.ylabel('Volume of Items Types')
plt.xlabel('Type of Eligibility')
plt.title('Count of ELIGIBILITY TYPE')
label=['ACCOUNT','ITEM','CUSTOMER','OTHER','INQUIRY','REQUEST','CONTRACT'] 
#label =['Contract','ITEM','CUSTOMER','REQUEST','ACCOUNT','INQUIRY','OTHER']
#plt.legend(m,label)
plt.legend([bar for bar in bar_plot],label,loc=2,fontsize='xx-small')
#plt.figure(figsize =(4,5))
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Eligibility Type_fig.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %%
def category_count(x):
    return sum(Elig_Subject_line['ELIGIBILITY TYPE'].str.count(x))
Cat_Count=map(lambda x: category_count(x),['CONTRACT','ITEM','CUSTOMER','REQUEST','ACCOUNT','INQUIRY','Other'])

[a,b,c,d,e,f,g] = list(Cat_Count)

m=[a,b,c,d,e,f,g]

import numpy as np
import matplotlib.pyplot as plt
import math
Categories = ('CO','IT','CU','RE','AC','IN','Other')
# high = max(m)
# low = min(m)
bar_plot=plt.bar(np.arange(len(m)),m,width =0.5,align ='center',color = ['black', 'red', 'green', 'blue', 'orange','purple',
                                                                'brown'])
plt.xticks(np.arange(len(m)), Categories)
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
plt.ylabel('Volume of Items Types')
plt.xlabel('Type of Eligibility')
plt.title('Count of ELIGIBILITY TYPE')
label =['Contract','ITEM','CUSTOMER','REQUEST','ACCOUNT','INQUIRY','OTHER']
#plt.legend(m,label)
plt.legend([bar for bar in bar_plot],label,loc=1,fontsize='xx-small')
#plt.figure(figsize =(4,5))
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Eligibility Type.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %%
OD_time=pd.DataFrame(OD_time)

OD_time=OD_time.fillna(method ='ffill')
OD_time['Subject_Line'] = Subject_line
OD_time

# Without Outlier
print(OD_time['OpenDuration'].describe())

std = OD_time['OpenDuration'].std()
# Out:
# count     1926.000000
# mean       222.373313
# std       2049.450170
# min          4.000000
# 25%         42.000000
# 50%         89.000000
# 75%        171.000000
# max      70175.000000
# Name: OpenDuration, dtype: float64

# %%
OD_time['Subject_Line'][OD_time['OpenDuration']<OD_time['OpenDuration'].mean()]
timing=OD_time['OpenDuration'][OD_time['OpenDuration']<OD_time['OpenDuration'].mean()]

# %%
OD_time['Subject_Line'][OD_time['OpenDuration']<OD_time['OpenDuration'].mean()]
# Out:
# 0       *Second Request* - FW: [EXTERNAL] *Second Requ...
# 1       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 3       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 4       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 5       [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...
# 6       [EXTERNAL] * nbr * Rebate inquiry to KENDALL H...
# 7       [EXTERNAL] **GHX 5.22.18** UNITYPOINT HEALTH -...
# 8       [EXTERNAL] *Second Request* - Contract Eligibi...
# 9       [EXTERNAL] *URGENT* MCKESSON PREMIER NEW CUSTO...
# 10      [EXTERNAL] *Urgent* MedAssets Contract Expirat...
# 11      [EXTERNAL] : Rebate inquiry to COVIDIEN RESPIR...
# 13      [EXTERNAL] [KD] GPO Change Notification - CROS...
# 15      [EXTERNAL] [KD] GPO Change Notification - MedA...
# 16      [EXTERNAL] [KD] GPO Change Notification - NORT...
# 17      [EXTERNAL] [KD] New Account, Contract Eligibil...
# 18      [EXTERNAL] [KD] New Account, Contract Eligibil...
# ...

# %%
plt.hist(timing,histtype='bar',bins=150)
plt.xlabel('Time to close a Query')
plt.ylabel('Frequency Count')
plt.title('Time take below mean Histogram')
plt.show()

# %%
timing=OD_time['OpenDuration'][OD_time['OpenDuration']>OD_time['OpenDuration'].mean()]

plt.hist(timing,histtype='bar',bins=150)
plt.xlabel('Time to close a Query')
plt.ylabel('Frequency Count')
plt.title('Time take above mean Histogram')
plt.show()

# %%
time = OD_time['OpenDuration'][OD_time['OpenDuration']<60]
plt.scatter(range(len(time)),time,c='red')
plt.xlabel('No of Query')
plt.ylabel('Time Taken to close it')
plt.title('Time take below 1hour')

plt.show()

# %%
time = OD_time['OpenDuration'][OD_time['OpenDuration']>600]
plt.scatter(range(len(time)),time)
plt.xlabel('No of Query')
plt.ylabel('Time Taken to close it')
plt.title('Time take above mean')

plt.show()

# %%
time = list(OD_time['OpenDuration'])

time
plt.scatter(range(len(time)),time)
plt.show()

# %%
time = OD_time['OpenDuration'][OD_time['OpenDuration'] < 800]
subject = OD_time['Subject_Line'][OD_time['OpenDuration']<800]

# %%
N_df = pd.DataFrame(time)
N_df.describe()
# Out:
#        OpenDuration
# count   1891.000000
# mean     131.048123
# std      137.516326
# min        4.000000
# 25%       42.000000
# 50%       87.000000
# 75%      165.000000
# max      791.000000

# %%
N_df['Subject'] = subject

#N_df.to_csv(r'D:\Users\703183779\Documents\Mounika\AAAD_Eligibility.csv',sep=",")
#df.to_csv(r'D:\Users\703183779\Documents\Mounika\AAAD_WITH_CONTRACT_CATEGORY_NAME_V1.csv',sep=",")

total_eligibility = len(N_df['Subject'])
total_eligibility

subject_list = list(N_df.Subject)
Med_C = 0
Car_C = 0
Mck_C = 0
GPO_C = 0
Other_C =0
Other = []
elig_cat =[]
for i in subject_list:
    if any(word in i for word in ['Medline','MEDLINE','medline']):
        #df['Contract Name'] = df['Contract Name'].append("Contract Eligibility")
        Med_C = Med_C+1
        elig_cat.append('Medline')
    elif any(word in i for word in ['Cardinal','CARDINAL','cardinal']):
        Car_C = Car_C+1
        elig_cat.append('Cardinal')
    elif any(word in i for word in ['McKesson','MCKESSON','Mckesson','Mck']):
        Mck_C = Mck_C+1
        elig_cat.append('Mckesson')
    elif any(word in i for word in ['PREMIER','Premier','MEDASSETS','VIZIENT','Vizient','INTALERE','HEALTHTRUST','HPG','ROI','GPO','gpo']):
        GPO_C = GPO_C+1
        elig_cat.append('GPO')
    else:
        Other_C = Other_C+1
        elig_cat.append('Other')
        
print(Med_C,Car_C,Mck_C,GPO_C,Other_C)
# Out:
# 323 4 22 527 1015

# %%
N_df['Elig_Cat'] = elig_cat

# %%
N_df.head()
N_df.to_csv(r'D:\Users\703183779\Documents\Mounika\Eligibility_Supplier.csv',sep=",")

# %%
# Out:
# 886

# %%
import matplotlib.pyplot as plt
array = [Med_C,Car_C,Mck_C,GPO_C,Other_C]
explode = (0.1, 0.3, 0.5, 0.1,0.0)
labels = ['Medline','Cardinal','Mckesson','GPO','Others']
plt.pie(array,explode,labels,colors =('red', 'black', 'yellow', 'orange', 'green'),labeldistance=1.1,shadow=True)
plt.title('Eligibility Criteria',loc='center')
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Eligibility_figure.JPEG',dpi=150,orientation='landscape',figsize =(6,6)) 

#plt.legend(labels,loc=1)
plt.show()
bar_plot=plt.bar(np.arange(len(array)),array,width =0.3,align ='center',color = ['red', 'black', 'yellow', 'orange', 'green'])

plt.legend([bar for bar in bar_plot],labels,fontsize='xx-small',loc=2)
plt.title("Eligibility Criteria")
plt.ylabel("Volume of items")
plt.xlabel("Eligibility Category")
plt.xticks(np.arange(len(array)),labels)
plt.savefig(r'D:\Users\703183779\Documents\Mounika\Eligibility_figure_barplot.JPEG',dpi=400,orientation='landscape',figsize =(6,6)) 
plt.show()

# %% [markdown]
# # Categorise for time taken in different category of data

# %%
"""Medline"""
Medline=N_df['OpenDuration'][N_df['Elig_Cat']=='Medline']
Medline = list(Medline)

Medline
plt.figure(1)

plt.scatter(range(len(Medline)),Medline,color ='red')
plt.title("Scatter plot of Medline data with OpenDuration")
plt.ylabel("Time Duration")
plt.subplot(2,2,1)
#plt.show()

#print(pd.DataFrame(Medline).describe())

""" GPO """
GPO=N_df['OpenDuration'][N_df['Elig_Cat']=='GPO']
GPO = list(GPO)

GPO
plt.figure(2)
plt.scatter(range(len(GPO)),GPO,color ='orange')
plt.title("Scatter plot of GPO data with OpenDuration")
plt.ylabel("Time Duration")
plt.subplot(2,2,2)
#plt.show()
#print(pd.DataFrame(GPO).describe())

"""Other"""
Other=N_df['OpenDuration'][N_df['Elig_Cat']=='Other']
Other = list(Other)

plt.figure(3)
plt.scatter(range(len(Other)),Other,color ='green')
plt.title("Scatter plot of Other data with OpenDuration")
plt.ylabel("Time Duration")
plt.subplot(2,2,3)
# plt.show()
# print(pd.DataFrame(Other).describe())

"""Mckesson"""
Mckesson=N_df['OpenDuration'][N_df['Elig_Cat']=='Mckesson']
Mckesson = list(Mckesson)
plt.figure(4)
plt.scatter(range(len(Mckesson)),Mckesson,color ='yellow')
plt.title("Scatter plot of Mckesson data with OpenDuration")
plt.ylabel("Time Duration")
plt.subplot(2,2,4)
plt.show()
# plt.show()
# print(pd.DataFrame(Mckesson).describe())

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-eab7ae1cd57c> in <module>()
#       8
#       9 ax.scatter(range(len(Medline)),Medline,color ='red')
# ---> 10 ax.title("Scatter plot of Medline data with OpenDuration")
#      11 ax.ylabel("Time Duration")
#      12
#
# TypeError: 'Text' object is not callable

# %% [markdown]
# ## Scatter plot of Medline data with OpenDuration

# %%
Medline=N_df['OpenDuration'][N_df['Elig_Cat']=='Medline']
Medline = list(Medline)

Medline
plt.scatter(range(len(Medline)),Medline,color ='red')
plt.legend("Medline")
plt.title("Scatter plot of Medline data with OpenDuration < 800 min")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
#plt.legend("Med")
plt.show()

print(pd.DataFrame(Medline).describe())


plt.boxplot(Medline,vert=False)
plt.title("Boxplot of Medline Data")
plt.xlabel("Time taken in minutes")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Medline_BoxPlot.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count  323.000000
# mean   126.996904
# std    132.088374
# min      5.000000
# 25%     48.000000
# 50%     84.000000
# 75%    145.500000
# max    729.000000

# %%
GPO=N_df['OpenDuration'][N_df['Elig_Cat']=='GPO']

# %% [markdown]
# ### Scatter plot of GPO data with OpenDuration

# %%
GPO=N_df['OpenDuration'][N_df['Elig_Cat']=='GPO']
GPO = list(GPO)

GPO
plt.scatter(range(len(GPO)),GPO,color ='orange')
plt.title("Scatter plot of GPO data with OpenDuration")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\GPO_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.legend('GPO')
plt.show()
print(pd.DataFrame(GPO).describe())

plt.boxplot(GPO,vert=False)
plt.xlabel("Time taken in minutes")
plt.title("Box plot of GPO Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\GPO_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count  527.000000
# mean   111.827324
# std    129.586042
# min      7.000000
# 25%     30.000000
# 50%     67.000000
# 75%    144.000000
# max    777.000000

# %% [markdown]
# ### Scatter plot of Other data with OpenDuration

# %%
Other=N_df['OpenDuration'][N_df['Elig_Cat']=='Other']
Other = list(Other)


plt.scatter(range(len(Other)),Other,color ='green')
plt.title("Scatter plot of Other data with OpenDuration")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Other_Scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
print(pd.DataFrame(Other).describe())
plt.boxplot(Other,vert=False)
plt.xlabel("Time taken in minutes")
plt.title("Box plot of Other Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Other_Box.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                  0
# count  1015.000000
# mean    141.009852
# std     139.646623
# min       4.000000
# 25%      48.000000
# 50%     100.000000
# 75%     176.500000
# max     791.000000

# %% [markdown]
# ### Scatter plot of Mckesson data with OpenDuration

# %%
Mckesson=N_df['OpenDuration'][N_df['Elig_Cat']=='Mckesson']
Mckesson = list(Mckesson)


plt.scatter(range(len(Mckesson)),Mckesson,color ='black')
plt.title("Scatter plot of Mckesson data with OpenDuration")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Mckesson_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
print(pd.DataFrame(Mckesson).describe())
plt.boxplot(Mckesson,vert=False)
plt.xlabel("Time taken in minutes")
plt.title("Box plot of Mckesson Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Mckesson_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
# Out:
#                 0
# count   22.000000
# mean   144.090909
# std    186.382839
# min      4.000000
# 25%      9.500000
# 50%     60.500000
# 75%    164.750000
# max    518.000000

# %%
"""Cardinal"""
Cardinal=N_df['OpenDuration'][N_df['Elig_Cat']=='Cardinal']
Cardinal = list(Cardinal)


plt.scatter(range(len(Cardinal)),Cardinal,color ='grey')
plt.title("Scatter plot of Mckesson data with OpenDuration")
plt.ylabel("Time Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Cardinal_scatter.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
print(pd.DataFrame(Cardinal).describe())
plt.boxplot(Cardinal,vert=False)
plt.xlabel("Time taken in minutes")
plt.title("Box plot of Cardinal Data")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\Cardinal_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
Cardinal
# Out:
#                 0
# count    4.000000
# mean   391.000000
# std    265.775595
# min     89.000000
# 25%    241.250000
# 50%    380.000000
# 75%    529.750000
# max    715.000000
# [468.0, 292.0, 89.0, 715.0]

# %%
Inc_time=df['OpenDuration'][df['Contract Category']=='Incident']
Subject_line = df['OriginalSubject'][df['Contract Category']=='Incident']

Inc_time=Inc_time.fillna(method='pad')

# %%
Incident=pd.DataFrame(Inc_time)
Incident['Subject Line'] = list(Subject_line)
Incident['OpenDuration'].fillna(method='pad')
Incident.to_csv(r"D:\Users\703183779\Documents\Mounika\Incident.csv",sep=",",index_col=1)

time_incident=list(Incident.OpenDuration)
plt.boxplot(time_incident,vert=False)
plt.xlabel('Time Taken in minute')
plt.title("Incident Open Duration")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\INCIDENT_BOXPLOT.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()

# %%
Inc_time.describe()
# Out:
# count     803.000000
# mean      208.306351
# std       344.255054
# min         6.000000
# 25%        70.000000
# 50%       127.000000
# 75%       226.500000
# max      5826.000000
# Name: OpenDuration, dtype: float64

# %% [markdown]
# ### Plotting data with below 400min time duration

# %%
#Inc_time['Open Duration'][Inc_time['Open Duration']<400]
inc_time=list(Incident['OpenDuration'][Incident['OpenDuration']<400])
plt.boxplot(inc_time,vert=False)
plt.xlabel('Time Taken in minute')
plt.title("Incident Open Duration Below 400 min")
plt.savefig(r"D:\Users\703183779\Documents\Mounika\Box Plot and Scatter plot\INCIDENT_BOXPLOT_Below400.JPEG",dpi=150,orientation='landscape',figsize =(6,6))
plt.show()
Incident['OpenDuration'][Incident['OpenDuration']<400].describe()
# Out:
# count    721.000000
# mean     137.689320
# std       89.149067
# min        6.000000
# 25%       66.000000
# 50%      113.000000
# 75%      192.000000
# max      396.000000
# Name: OpenDuration, dtype: float64

# %%
O_time=df['OpenDuration'][df['Contract Category']=='Other']
O_Subject_line = df['OriginalSubject'][df['Contract Category']=='Other']


Other_df = pd.DataFrame(O_time)
Other_df['Subject Line'] = list(O_Subject_line)

# %%
Other_df.to_csv(r"D:\Users\703183779\Documents\Mounika\Other.csv",sep=",")

# %%
# Out:
#       OpenDuration                                       Subject Line
# 19             6.0          [EXTERNAL] ☀️ We're Having Fun in the Sun
# 20           328.0                                [EXTERNAL] 05507-11
# 21            55.0                                   [EXTERNAL] 05614
# 22           135.0            [EXTERNAL] 05740-4 - LOCAL - MONTEFIORE
# 23             NaN            [EXTERNAL] 05740-4 - LOCAL - MONTEFIORE
# 24           101.0                                [EXTERNAL] 05855-1
# 30           681.0        [EXTERNAL] 1007870-Covidien-Stratum-1-31-18
# 34           187.0  [EXTERNAL] 1012696-COVIDIEN-ACADIA-G7808-G7410...
# 40            88.0  [EXTERNAL] 10754/10759 Memorial Gulfport-Bilox...
# 42            18.0               [EXTERNAL] 10968 North Oaks - Walker
# 44           130.0           [EXTERNAL] 11056921 | Summit Orthopedics
# 45            61.0                   [EXTERNAL] 11126409|OSI|Covidien
# ...

# %%
Subject_line.describe()
# Out:
# count                                         803
# unique                                        764
# top       [EXTERNAL] Update For Incident# 1467518
# freq                                            7
# Name: OriginalSubject, dtype: object

# %%
Inc_time = Inc_time.fillna(method ='backfill')
print(Inc_time.describe())
Inc_time = list(Inc_time)
# Out:
# count     803.000000
# mean      207.408468
# std       344.351550
# min         6.000000
# 25%        69.000000
# 50%       127.000000
# 75%       224.000000
# max      5826.000000
# Name: OpenDuration, dtype: float64

# %%
Inc_time
# Out:
# 2363    221.0
# 2369    104.0
# 2372    129.0
# 2375     65.0
# 2376    869.0
# 2380    711.0
# 2381     39.0
# 2382     92.0
# 2384     86.0
# 2387    458.0
# 2388    443.0
# 2390    330.0
# 2393     73.0
# 2394    210.0
# 2397    228.0
# 2398      9.0
# 2399     88.0
# 2400    139.0
# 2402    873.0
# 2454    300.0
# 2455    139.0
# 2456     33.0
# 2457    238.0
# 2458     36.0
# 2459    344.0
# 2460    119.0
# 2461    112.0
# 2462     74.0
# 2463     90.0
# 2464    183.0
#         ...
# 4537     56.0
# 4538     55.0
# 4539    179.0
# 4541    160.0
# 4547    377.0
# 4553     75.0
# 4554     78.0
# 4570     64.0
# 4679    741.0
# 4688    172.0
# 4706     91.0
# 4837    729.0
# 4840      NaN
# 4842     46.0
# 4843     76.0
# 4846     34.0
# 4906    605.0
# 4907    137.0
# 4927     38.0
# 4928     22.0
# 4929      NaN
# 4948      NaN
# 4949    233.0
# 4950    643.0
# 4951     58.0
# 4955     15.0
# 4956     58.0
# 4957     63.0
# 5007     63.0
# 5009     92.0
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(Inc_time,vert=False,meanline=True,showmeans =True)
#plt.xticks([69,127,224],('1','2','3'))

plt.show()
Inc_time.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-ab7e4d92b5ee> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.boxplot(Inc_time,vert=False,meanline=True,showmeans =True)
#       3 #plt.xticks([69,127,224],('1','2','3'))
#       4
#       5 plt.show()
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, hold, data)
#    2715                          meanprops=meanprops, capprops=capprops,
#    2716                          whiskerprops=whiskerprops,
# -> 2717                          manage_xticks=manage_xticks, data=data)
#    2718     finally:
# ...

# %%
plot = figure()
p

# %%
import bokeh

# %%
from bokeh.io import output_file,show

from bokeh.plotting import figure

plot = figure(plot_width = 400,tools ='pan,box_zoom')

plot.circle(x =10,y=[1,2,3,4,5],size =[12,6,5,2,3])

output_file('circle.html')

show(plot)
# Out:
# INFO:bokeh.core.state:Session output file 'circle.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="plotdiv" id="6d97440e-cc49-4192-a267-4342febd862d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
# ...

# %%
# Standard imports 

from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="66dc4d8e-25e0-419c-ba3a-3896cb62577c">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure()

plot.circle(x=10, y=[2,5,8,12], size =[10,20,30,40])

plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-344-ba93a274e588> in <module>()
#       3 plot.circle(x=10, y=[2,5,8,12], size =[10,20,30,40])
#       4
# ----> 5 plot.show()
#
# AttributeError: 'Figure' object has no attribute 'show'

# %%
# Create and deploy interactive data applications

from IPython.display import IFrame
IFrame('https://demo.bokehplots.com/apps/sliders', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://demo.bokehplots.com/apps/sliders"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import re

pattern = 'G[0-9]{4}'

pattern = re.compile(pattern)

re.findall(pattern,'[EXTERNAL] G6881 - COMMUNITY NURSING SERVICES (BUL - DISTRIBUTION CHANGE TO MEDLINE')
# Out:
# ['G6881']

# %%
std = N_df['OpenDuration'].std()
mean =N_df['OpenDuration'].mean()

# %%
time_scale = [(x-mean)/std for x in N_df['OpenDuration']]

# %%
time_scale
# Out:
# [-0.39675006216056247,
#  -0.22012377876630718,
#  1.0789340474882156,
#  -0.6930264084993133,
#  -0.35116908580075462,
#  -0.59046921168974564,
#  -0.32837859762085075,
#  -0.11756658195673959,
#  -0.11756658195673959,
#  -0.51640012510505795,
#  -0.51640012510505795,
#  -0.18024042445147534,
#  1.1985841104327111,
#  0.12173354393225144,
#  -0.71581689667921722,
#  -0.50500488101510599,
#  -0.66453829827443334,
#  -0.65314305418448138,
#  0.12173354393225144,
#  0.11033829984229949,
#  0.98777209476859995,
#  -0.6759335423643853,
#  -0.77279311712897691,
#  -0.14605469218161948,
#  -0.54488823532993791,
#  0.30975507141645869,
#  -0.26000713308113899,
#  -0.60756207782467364,
#  0.1331287880222034,
#  -0.30558810944094683,
#  0.036269213257611788,
#  -0.6018644557796976,
#  2.207063212393459,
#  -0.38535481807061051,
#  -0.38535481807061051,
#  -0.22012377876630718,
#  -0.53919061328496187,
#  -0.27709999921606693,
#  0.41800989027100222,
#  -0.45372628261032222,
# ...

# %%
plt.hist(time_scale,bins=100,color='red')
plt.show()

# %%
import numpy as np
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
y_pos
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#               orientation='portrait', papertype=None, format=None,
#               transparent=False, bbox_inches=None, pad_inches=0.1,
#               frameon=None)
#
#     The output formats available depend on the backend being used.
#
#     Arguments:
#
#       *fname*:
#         A string containing a path to a filename, or a Python
#         file-like object, or possibly some backend-dependent object
#         such as :class:`~matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is *None* and *fname* is a string, the output
#         format is deduced from the extension of the filename. If
#         the filename has no extension, the value of the rc parameter
#         ``savefig.format`` is used.
#
# ...

# %%
help(np.arange)
# Out:
# Help on built-in function arange in module numpy.core.multiarray:
#
# arange(...)
#     arange([start,] stop[, step,], dtype=None)
#
#     Return evenly spaced values within a given interval.
#
#     Values are generated within the half-open interval ``[start, stop)``
#     (in other words, the interval including `start` but excluding `stop`).
#     For integer arguments the function is equivalent to the Python built-in
#     `range <http://docs.python.org/lib/built-in-funcs.html>`_ function,
#     but returns an ndarray rather than a list.
#
#     When using a non-integer step, such as 0.1, the results will often not
#     be consistent.  It is better to use ``linspace`` for these cases.
#
#     Parameters
#     ----------
#     start : number, optional
#         Start of interval.  The interval includes this value.  The default
#         start value is 0.
#     stop : number
#         End of interval.  The interval does not include this value, except
# ...

# %%
category ={'Contract Eligibility':['Eligibility','Rebate inquiry','item','CUSTOMER','Expiration','GPO Change Notification',
                                  'MEDICAL CENTER'],
          'Contract Pricing':['Pricing'],
          'Approval Contract':['Approval']}

# category ={('Eligibility','Rebate inquiry','item','CUSTOMER','Expiration','GPO Change Notification',
#                                   'MEDICAL CENTER'):'Contract Eligibility',
#           'Pricing':'Contract Pricing',
#           'Contract':'Approval'}

contract_name =[]


def contains(subject,dictionary):
    for i in subject:
        for key,value in dictionary.items():
            if any(word in i for word in value):
                contract_name.append(key)
            else:
                contract_name.append("other")
    return contract_name            

# for i in subject:
#     for key,value in category.items():
#         if value in i:
#             contract_name.append(key)
#         else:
#             contract_name.append("Others")

contract_name=contains(subject,category)
contract_name
# Out:
# ['other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
#  'Contract Eligibility',
#  'other',
#  'other',
# ...

# %%
contract_name =[]
for i in subject:
    for key,value in category.items():
        if any(word in i for word in value):
            contract_name.append(key)
        else:
            contract_name.append("other")
len(contract_name)
# Out:
# 15039

# %%
if any(word in 'some one long two phrase three' for word in l):
    print("yes")
# Out:
# yes

# %%
df['Contract_Category'] = contract_name

# %%
contract_name.count('Pricing')
#contract_name.count('Approval')
# Out:
# 99

# %%
contract_name.count('Other')
# Out:
# 3183

# %%
len(contract_name)
# Out:
# 5013

# %%
df.columns
# Out:
# Index(['UserDepartment', 'MailFrom', 'Flag', 'OriginalSubject', 'LastName',
#        'FirstName', 'ArrivalTime', 'OpenTime', 'ClosedTime', 'OpenDuration',
#        'Name', 'ID', 'TextValue', 'Contract_Category'],
#       dtype='object')

# %%
df['FirstName'].unique()
# Out:
# array(['Megha', 'Uzma', 'Mounika', 'Amulya', 'Syed', 'Divya', 'Kranthi',
#        'Gopala', 'Sruthi', 'Dhruvananda', 'Simhachalam', 'P sai', 'Tina',
#        'Santosh'], dtype=object)

# %%
df.head()
# Out:
#             UserDepartment              MailFrom     Flag  \
# 0  Genpact Group Contracts  Div17CnR@medline.com  Medline
# 1  Genpact Group Contracts  ASantera@medline.com  Medline
# 2  Genpact Group Contracts  ASantera@medline.com  Medline
# 3  Genpact Group Contracts  ASantera@medline.com  Medline
# 4  Genpact Group Contracts  ASantera@medline.com  Medline
#
#                                      OriginalSubject LastName FirstName  \
# 0  *Second Request* - FW: [EXTERNAL] *Second Requ...   Thakur     Megha
# 1  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Zaheer      Uzma
# 2  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Zaheer      Uzma
# 3  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...   Thakur     Megha
# 4  [EXTERNAL] * NBR * Rebate inquiry to COVIDIEN ...    Punna   Mounika
#
#           ArrivalTime            OpenTime          ClosedTime  OpenDuration  \
# 0 2018-01-15 09:57:03 2018-01-18 05:52:36 2018-01-18 05:53:50          74.0
# ...

# %%
import pandas as pd

file = pd.read_excel("D:\Sid project\MASTER LIST-Fortis Conveyed Items.xlsx")

file = pd.DataFrame(file)

file
# Out:
#              Item                Item Description Divest Code  \
# 0         MW00617  T101 ALLIG CLP ADPTW/4MM SKT 1         CAH
# 1         MW00622  N08/W PNCH CLIP ADPTER 4MM WHT         CAH
# 2         MW01190   R7R1536  RADIOLUCENT LDWR DIN         CAH
# 3         MW04260  A11A CLIP ADAPT RIGID .125 SKT         CAH
# 4         MW05000   2320-S 3 LEAD ONE PIECE CABLE         CAH
# 5         MW05025   2355-36S 3 LEAD ONE PIECE CBL         CAH
# 6      7772990170       MISCELLANEOUS SCD CHARGES         CAH
# 7      7773990170                SCD ROYALTY FEES         CAH
# 8      7774990150       MISC. ENTERAL PUMP CHARGE         CAH
# 9      7774990160        MISC. THERMOMETRY CHARGE         CAH
# 10     7774990170       MISCELLANEOUS AVI CHARGES         CAH
# 11     7775990170          FOOT PUMP ROYALTY FEES         CAH
# 12     7776990170        SCD TRANS AGREEMENT FEES         CAH
# 13     7777990170  FOOT PUMP TRANS AGREEMENT FEES         CAH
# ...

# %%
l = [1,2,3,4]

# %%
for i in range(10):
    if(i==5):
        break
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
set([1,1,1,2,3,4,5])
# Out:
# {1, 2, 3, 4, 5}

# %%
import bokeh

# %%
import os
os.getcwd()
# Out:
# 'D:\\Users\\703183779\\Documents'

# %%
string = """Iʼm % student from S%g%r, M%dhy% Pr%desh, % sm%ll town in Indi%. I think it
will be benefici%l for my thesis work. But Iʼve no job of my own to c%rry the
exp%nses to p%y for the certific%te of this course. I live only for
Govt.schol%rship (1840rs or %bout $30 per month). In this circumst%nce,
it is very much difficult for me to g%ther such %mount of money for the
certific%te. Fin%nci%l Aid will help me t%ke this course without %ny %dverse
imp%ct on my monthly essenti%l needs. So Iʼm b%dly in need of this
fin%nci%l %id.
I w%nt to t%ke this course %s I w%nt to le%rn Deep le%rning %nd Neur%l
network %nd i love the style of te%ching by Prof. Andrew Ng %nd re%lly
excited for this course.
My F%ther is % f%rmer we %re f%mily of five, my f%ther income is only
source of income, his money is invested on running our house properly, we
found it difficult to h%ve % bro%db%nd connection we %re h%rdly m%n%ging
it, p%ying for this course is beyond our limits.
I will be re%lly th%nkful to Courser% to provide me this course, they will
help % underprivileged student like me. This will indeed help me to %chieve
go%l in my life %nd in turn r%ise our f%mily income."""

# %%
a=string.replace("%","a")
a =a.replace("\n"," ")

# %%
a
# Out:
# 'Iʼm a student from Sagar, Madhya Pradesh, a small town in India. I think it will be beneficial for my thesis work. But Iʼve no job of my own to carry the expanses to pay for the certificate of this course. I live only for Govt.scholarship (1840rs or about $30 per month). In this circumstance, it is very much difficult for me to gather such amount of money for the certificate. Financial Aid will help me take this course without any adverse impact on my monthly essential needs. So Iʼm badly in need of this financial aid. I want to take this course as I want to learn Deep learning and Neural network and i love the style of teaching by Prof. Andrew Ng and really excited for this course. My Father is a farmer we are family of five, my father income is only source of income, his money is invested on running our house properly, we found it difficult to have a broadband connection we are hardly managing it, paying for this course is beyond our limits. I will be really thankful to Coursera t
# ...

# %%
String = """I w'nt to complete Neur'l network 'nd Deep le'rning course by Prof. Andrew
Ng. Course will boost my job prospects. will help perform better in c'rrying out
D't' Science project which 're in k'ggle 'nd other website, 'nd give 'lso me
'n edge over my competitors. A verified certific'te will 'tt'ch credibility to the
certific'te I receive from this course.
Neur'l network 'nd Deep le'rning 're hot topics in field of D't' science 'nd
every concept is will improve my underst'nding which in r'ther help me to
'chieve my go'ls of D't' scientist.
I pl'n to complete 'll 'ssignments on or before time. Also I intend to
p'rticip'te in Discussion Forums, which I h've found to supplement my
le'rning immensely in the other online courses I h've t'ken on Courser'. I 'lso
pl'n to gr'de 'ssignments which 're to peer reviewed which I believe will 'n
inv'lu'ble le'rning opportunity.
Also i think with enough underst'nding of concept it will re'lly help to h've '
good job in h'nd, 'nd Courser' will pl'y ' m'jor role in th't."""

# %%
a =String.replace("'","a")
a =a.replace("\n"," ")
a
# Out:
# 'I want to complete Neural network and Deep learning course by Prof. Andrew Ng. Course will boost my job prospects. will help perform better in carrying out Data Science project which are in kaggle and other website, and give also me an edge over my competitors. A verified certificate will attach credibility to the certificate I receive from this course. Neural network and Deep learning are hot topics in field of Data science and every concept is will improve my understanding which in rather help me to achieve my goals of Data scientist. I plan to complete all assignments on or before time. Also I intend to participate in Discussion Forums, which I have found to supplement my learning immensely in the other online courses I have taken on Coursera. I also plan to grade assignments which are to peer reviewed which I believe will an invaluable learning opportunity. Also i think with enough understanding of concept it will really help to have a good job in hand, and Coursera will play a 
# ...

# %%
import pandas as pd
df=pd.read_csv(r"D:\Users\703183779\Documents\Mounika\AAAD_Eligibility.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-46e196852261> in <module>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv(r"D:\Users\703183779\Documents\Mounika\AAAD_Eligibility.csv")
#
# ...

# %%
import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-161-367324541f54> in <module>()
# ----> 1 import Django
#
# ImportError: No module named 'Django'

# %%
import tensforflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-162-98da266494ea> in <module>()
# ----> 1 import tensforflow
#
# ImportError: No module named 'tensforflow'

# %%
import string
char=string.ascii_lowercase[:]

# %%
for i in enumerate(char):
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def only_upper(s):
    upper_chars = ""
    for char in s:
        if char.isupper():
            upper_chars += char
    return upper_chars

print (only_upper("HeLLo WorLD"))
# Out:
# HLLWLD

# %%
c="c"
c.upper()
# Out:
# 'C'

# %%
char=string.ascii_lowercase[:]
low_char=[]
for i in char:
    low_char.append(i)

# %%
low_char[0:len(low_char):2]
# Out:
# ['a', 'c', 'e', 'g', 'i', 'k', 'm', 'o', 'q', 's', 'u', 'w', 'y']

# %%
Upper_char=[]
for i in low_char:
    Upper_char.append(i.upper())

# %%
Upper_char
# Out:
# ['A', 'C', 'E', 'G', 'I', 'K', 'M', 'O', 'Q', 'S', 'U', 'W', 'Y']

# %%
"C" in Upper_char
# Out:
# True

# %%
import sys
import math
import string
# Auto-generated code below aims at helping you parse
# the standard input according to the problem statement.
char=string.ascii_lowercase[:]
low_char=[]
for i in char:
    low_char.append(i)
    
Upper_char=[]
for i in low_char:
    Upper_char.append(i.upper())

new_list =[]
new_list =Upper_char+low_char


s = input()
new_string=""
for i in new_list:
    if i in low_char:
        new_string=i.upper()

# %%
msg ="I am Akash Soni"
"".join(msg.split(sep=" "))
# Out:
# 'IamAkashSoni'

# %%
import string
char=string.ascii_lowercase[:]

# %%
char
l =[]

# %%
for i in char:
    l.append(i)

# %%
d ={}

# %%
d={}
for index,val in enumerate(l):
    d.update({val:index})

# %%
msg = "i am a programmer"

# %%
code ="ab"

# %%
msg="".join(msg.split(" "))

# %%
new_code=""
for i in range(len(msg)):
    if(len(code)!=len(msg)):
        new_code+=code
        i+=len(code)

# %%
new_code =new_code[:len(msg)]

# %%
new_code
# Out:
# 'ababababababab'

# %%
for i in msg:
    for j in new_code:

# %%
prev_count =0
k=0
n = int(input())

for i in range(n):
    k=10**i+prev_count
    prev_count=k
    print(k*n)
# Out:
# 4
# 4
# 44
# 444
# 4444
